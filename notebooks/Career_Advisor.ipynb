# %% [markdown]
# <a href="https://colab.research.google.com/github/matinapap/Career-Advisor-Chatbot/blob/main/notebooks/Career_Advisor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Career Advisor Chatbot Demo
#
# This notebook is now a lightweight Google Colab demo. The app logic lives in the `career_advisor/` package; this notebook only orchestrates setup and launch.

# %% [markdown]
# ## 1. Optional: Mount Google Drive
#
# Run this only if the project is stored in Google Drive. If you opened the notebook directly from GitHub, skip this cell and clone the repository instead.

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Career-Advisor-Chatbot

# %% [markdown]
# ## Alternative: Clone from GitHub
#
# Use this if you opened only the notebook in Colab and the project files are not already available.

# %%
# !git clone https://github.com/matinapap/Career-Advisor-Chatbot.git
# %cd Career-Advisor-Chatbot

# %% [markdown]
# ## 2. Install Dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Set Python Path
#
# Run this after cloning or changing into the project folder so Colab can import the `career_advisor` package reliably.

# %%
import os
import sys
from pathlib import Path


def find_project_root():
    candidates = [Path.cwd(), *Path.cwd().parents, Path('/content/Career-Advisor-Chatbot')]
    for candidate in candidates:
        if (candidate / 'career_advisor').is_dir() and (candidate / 'requirements.txt').is_file():
            return candidate
    raise RuntimeError(
        'Could not find the project root. Run the clone cell first, then run `%cd /content/Career-Advisor-Chatbot`.'
    )


PROJECT_ROOT = find_project_root()
os.chdir(PROJECT_ROOT)
os.environ['PYTHONPATH'] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f'Project root: {PROJECT_ROOT}')
print('PYTHONPATH set for this Colab session.')

# %% [markdown]
# ## 4. Configure Secrets
#
# For the default open-source model, use a GPU runtime: Runtime → Change runtime type → T4 GPU. No Gemini key is required. Optionally add `SERPAPI_KEY` in Colab Secrets for course search. You can override the model with `HF_MODEL_ID`.

# %% [markdown]
# ## 5. Optional: Run Tests
#
# Run this cell after installing dependencies if you want to validate the package before launching the app.

# %%
# !PYTHONPATH=$PWD pytest -q

# %% [markdown]
# ## 6. Launch the App

# %%
import os
import sys
from pathlib import Path


def find_project_root():
    candidates = [Path.cwd(), *Path.cwd().parents, Path('/content/Career-Advisor-Chatbot')]
    for candidate in candidates:
        if (candidate / 'career_advisor').is_dir() and (candidate / 'requirements.txt').is_file():
            return candidate
    raise RuntimeError(
        'Could not find the project root. Run the clone cell first, then run `%cd /content/Career-Advisor-Chatbot`.'
    )


PROJECT_ROOT = find_project_root()
os.chdir(PROJECT_ROOT)
os.environ['PYTHONPATH'] = str(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f'Project root: {PROJECT_ROOT}')
print('PYTHONPATH set for this Colab session.')

from career_advisor.app import demo

demo.launch(share=True, debug=False)
